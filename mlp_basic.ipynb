# %%
import random
import torch

words = open('names.txt', 'r').read().splitlines()
words = sorted(list(set(words))) # set cause uncontrollable randomness， sorted for reproducibility
random.seed(42)
random.shuffle(words)
len(words)

chs = list(set(''.join(words + ['.'])))
chs = sorted(chs, reverse=False)
stoi = {ch: i for i, ch in enumerate(chs)}
itos = {i: ch for i, ch in enumerate(chs)}

# predict next token use previous 3 tokens
X, Y = [], []

for w in words:
    context = '...'
    for ch in w + '.':
        x = [stoi[c] for c in context]
        y = stoi[ch]
        X.append(x)
        Y.append(y)
        context = context[1:] + ch

X = torch.tensor(X)
Y = torch.tensor(Y)
n1, n2  = int(0.8 * len(X)), int(0.9 * len(X))

X_train, X_val, X_test = X.tensor_split([n1, n2])
Y_train, Y_val, Y_test = Y.tensor_split([n1, n2])

X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape
# Out:
# (torch.Size([169062, 3]),
#  torch.Size([21133, 3]),
#  torch.Size([21133, 3]),
#  torch.Size([169062]),
#  torch.Size([21133]),
#  torch.Size([21133]))

# %% [markdown]
# dataset should be split into 3 sets: train, val, test
# - train: for track optimization process
# - val: for hyperparameter tuning
# - test: for testing, only used it very rarely to avoid overfitting

# %% [markdown]
# # search for initial lr

# %%
import torch.nn.functional as F
import matplotlib.pyplot as plt

torch.manual_seed(42)
C = torch.randn(27, 2)
w1 = torch.randn(6, 100)
b1 = torch.randn(100)
w2 = torch.randn(100, 27)
b2 = torch.randn(27)
params = [C, w1, b1, w2, b2]
for p in params:
    p.requires_grad = True

bs = 64
n_steps = 1000

lre = torch.linspace(-3, 0, n_steps)
lri = 10 ** lre
lossi = []


indices = torch.randperm(X_train.shape[0])
X_train, Y_train = X_train[indices], Y_train[indices]
for s in range(n_steps):
    x = X_train[s * bs:(s + 1) * bs]
    y = Y_train[s * bs:(s + 1) * bs]
    emb = C[x].view(x.shape[0], -1)
    logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
    loss = F.cross_entropy(logits, y)

    loss.backward()
    with torch.no_grad():
        emb = C[X_val].view(X_val.shape[0], -1)
        logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
        val_loss = F.cross_entropy(logits, Y_val)
    lr = lri[s]
    for p in params:
        p.data -= lr * p.grad
        p.grad = None
    lossi.append(val_loss.item())
    

plt.plot(lri, lossi)
plt.xlabel('lr')
plt.ylabel('loss')
plt.show()
plt.plot(lre, lossi)
plt.xlabel('log_10 lr')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# almost same as re-runing for different lr

# %%
bs = 64
n_steps = 300
n_runs = 200

lre = torch.linspace(-3, 0, n_runs)
lri = 10 ** lre
lossi = []

for run in range(n_runs):
    lr = lri[run]

    torch.manual_seed(42)
    C = torch.randn(27, 2)
    w1 = torch.randn(6, 100)
    b1 = torch.randn(100)
    w2 = torch.randn(100, 27)
    b2 = torch.randn(27)
    params = [C, w1, b1, w2, b2]
    for p in params:
        p.requires_grad = True


    for s in range(n_steps):
        x = X_train[s * bs:(s + 1) * bs]
        y = Y_train[s * bs:(s + 1) * bs]
        emb = C[x].view(x.shape[0], -1)
        logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
        loss = F.cross_entropy(logits, y)

        loss.backward()
        for p in params:
            p.data -= lr * p.grad
            p.grad = None
    with torch.no_grad():
        emb = C[X_val].view(X_val.shape[0], -1)
        logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
        val_loss = F.cross_entropy(logits, Y_val)
        print(f"run: {run}, train loss: {loss.item():.4f} val_loss: {val_loss.item():.4f}")
    lossi.append(val_loss.item())
    

plt.plot(lri, lossi)
plt.xlabel('lr')
plt.ylabel('loss')
plt.title(f'different lr run for {n_steps} steps')
plt.show()
plt.plot(lre, lossi)
plt.xlabel('log_10 lr')
plt.ylabel('loss')
plt.title(f'different lr run for {n_steps} steps')
plt.show()
# Out:
# run: 0, train loss: 13.3199 val_loss: 12.9481
# run: 1, train loss: 13.2391 val_loss: 12.8670
# run: 2, train loss: 13.1571 val_loss: 12.7851
# run: 3, train loss: 13.0739 val_loss: 12.7026
# run: 4, train loss: 12.9895 val_loss: 12.6195
# run: 5, train loss: 12.9040 val_loss: 12.5359
# run: 6, train loss: 12.8174 val_loss: 12.4517
# run: 7, train loss: 12.7298 val_loss: 12.3669
# run: 8, train loss: 12.6413 val_loss: 12.2816
# run: 9, train loss: 12.5520 val_loss: 12.1957
# run: 10, train loss: 12.4620 val_loss: 12.1093
# run: 11, train loss: 12.3714 val_loss: 12.0224
# run: 12, train loss: 12.2805 val_loss: 11.9353
# run: 13, train loss: 12.1893 val_loss: 11.8478
# run: 14, train loss: 12.0979 val_loss: 11.7601
# run: 15, train loss: 12.0064 val_loss: 11.6722
# run: 16, train loss: 11.9148 val_loss: 11.5840
# run: 17, train loss: 11.8230 val_loss: 11.4953
# run: 18, train loss: 11.7306 val_loss: 11.4061
# run: 19, train loss: 11.6375 val_loss: 11.3160
# run: 20, train loss: 11.5435 val_loss: 11.2248
# run: 21, train loss: 11.4482 val_loss: 11.1325
# run: 22, train loss: 11.3515 val_loss: 11.0387
# run: 23, train loss: 11.2532 val_loss: 10.9435
# run: 24, train loss: 11.1534 val_loss: 10.8468
# run: 25, train loss: 11.0522 val_loss: 10.7488
# run: 26, train loss: 10.9498 val_loss: 10.6497
# run: 27, train loss: 10.8463 val_loss: 10.5497
# run: 28, train loss: 10.7422 val_loss: 10.4492
# run: 29, train loss: 10.6377 val_loss: 10.3483
# run: 30, train loss: 10.5330 val_loss: 10.2473
# run: 31, train loss: 10.4282 val_loss: 10.1464
# run: 32, train loss: 10.3233 val_loss: 10.0456
# run: 33, train loss: 10.2183 val_loss: 9.9448
# run: 34, train loss: 10.1131 val_loss: 9.8442
# run: 35, train loss: 10.0078 val_loss: 9.7436
# run: 36, train loss: 9.9021 val_loss: 9.6429
# run: 37, train loss: 9.7962 val_loss: 9.5420
# run: 38, train loss: 9.6899 val_loss: 9.4410
# run: 39, train loss: 9.5832 val_loss: 9.3398
# run: 40, train loss: 9.4762 val_loss: 9.2384
# run: 41, train loss: 9.3689 val_loss: 9.1368
# run: 42, train loss: 9.2613 val_loss: 9.0350
# run: 43, train loss: 9.1536 val_loss: 8.9330
# run: 44, train loss: 9.0457 val_loss: 8.8309
# run: 45, train loss: 8.9377 val_loss: 8.7286
# run: 46, train loss: 8.8297 val_loss: 8.6261
# run: 47, train loss: 8.7217 val_loss: 8.5234
# run: 48, train loss: 8.6137 val_loss: 8.4204
# run: 49, train loss: 8.5055 val_loss: 8.3169
# run: 50, train loss: 8.3972 val_loss: 8.2131
# run: 51, train loss: 8.2886 val_loss: 8.1087
# run: 52, train loss: 8.1798 val_loss: 8.0038
# run: 168, train loss: 3.6362 val_loss: 2.7923
# run: 169, train loss: 3.6656 val_loss: 2.7987
# run: 170, train loss: 3.7132 val_loss: 2.8130
# run: 171, train loss: 3.7233 val_loss: 2.8243
# run: 172, train loss: 3.7197 val_loss: 2.8349
# run: 173, train loss: 3.6905 val_loss: 2.8635
# run: 174, train loss: 3.7174 val_loss: 2.8729
# run: 175, train loss: 3.6963 val_loss: 2.8746
# run: 176, train loss: 3.6731 val_loss: 2.8977
# run: 177, train loss: 3.7124 val_loss: 2.9364
# run: 178, train loss: 3.7502 val_loss: 2.9241
# run: 179, train loss: 3.8081 val_loss: 2.9278
# run: 180, train loss: 3.8267 val_loss: 2.9283
# run: 181, train loss: 3.8988 val_loss: 2.9990
# run: 182, train loss: 3.8667 val_loss: 2.8675
# run: 183, train loss: 4.0494 val_loss: 2.9918
# run: 184, train loss: 3.9135 val_loss: 3.0860
# run: 185, train loss: 4.1176 val_loss: 3.1458
# run: 186, train loss: 4.1925 val_loss: 3.1097
# run: 187, train loss: 4.2130 val_loss: 3.1260
# run: 188, train loss: 4.5054 val_loss: 3.1741
# run: 189, train loss: 4.1013 val_loss: 3.1700
# run: 190, train loss: 4.4196 val_loss: 3.1323
# run: 191, train loss: 4.5143 val_loss: 3.3121
# run: 192, train loss: 4.6040 val_loss: 3.3902
# run: 193, train loss: 4.5148 val_loss: 3.0677
# run: 194, train loss: 4.9639 val_loss: 3.7355
# run: 195, train loss: 4.0595 val_loss: 3.6757
# run: 196, train loss: 4.3710 val_loss: 3.6154
# run: 197, train loss: 5.8227 val_loss: 5.0405
# run: 198, train loss: 4.3085 val_loss: 4.2575
# run: 199, train loss: 5.4482 val_loss: 4.0332

# %% [markdown]
# # visualize embedding

# %%
import torch.nn.functional as F

n_embd = 2
n_hidden = 100
bs = 64
n_steps = X_train.shape[0] // bs
ini_lr = 0.3
n_epochs = 30


torch.manual_seed(42)
g = torch.Generator().manual_seed(42)

C = torch.randn(27, n_embd)
w1 = torch.randn(3 * n_embd, n_hidden)
b1 = torch.randn(n_hidden)
w2 = torch.randn(n_hidden, 27)
b2 = torch.randn(27)
params = [C, w1, b1, w2, b2]
for p in params:
    p.requires_grad = True



step = 0
for epoch in range(n_epochs):


    indices = torch.randperm(X_train.shape[0], generator=g)
    X_tr, Y_tr = X_train[indices], Y_train[indices]
    for s in range(n_steps):
        x = X_tr[s * bs:(s + 1) * bs]
        y = Y_tr[s * bs:(s + 1) * bs]
        emb = C[x].view(x.shape[0], -1)
        logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
        loss = F.cross_entropy(logits, y)
    
        loss.backward()
        if step % 500 == 0:
            with torch.no_grad():
                emb = C[X_val].view(X_val.shape[0], -1)
                logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
                val_loss = F.cross_entropy(logits, Y_val)
            print(f"epoch: {epoch}, step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")
        for p in params:
            p.data -= lr * p.grad
            p.grad = None
        
        step += 1
        lr = ini_lr * (1 - 0.9 * step / n_steps / n_epochs)
# Out:
# epoch: 0, step: 0, train_loss: 14.9841, val_loss: 16.7180
# epoch: 0, step: 500, train_loss: 2.8562, val_loss: 2.8798
# epoch: 0, step: 1000, train_loss: 2.7706, val_loss: 2.6646
# epoch: 25, step: 66500, train_loss: 2.1277, val_loss: 2.2749
# epoch: 25, step: 67000, train_loss: 2.2652, val_loss: 2.2794
# epoch: 25, step: 67500, train_loss: 2.1651, val_loss: 2.2765
# epoch: 25, step: 68000, train_loss: 2.0636, val_loss: 2.2871
# epoch: 25, step: 68500, train_loss: 2.3349, val_loss: 2.2750
# epoch: 26, step: 69000, train_loss: 2.1602, val_loss: 2.2740
# epoch: 26, step: 69500, train_loss: 2.3400, val_loss: 2.2737
# epoch: 26, step: 70000, train_loss: 2.2171, val_loss: 2.2774
# epoch: 26, step: 70500, train_loss: 2.4259, val_loss: 2.2672
# epoch: 26, step: 71000, train_loss: 2.3108, val_loss: 2.2738
# epoch: 27, step: 71500, train_loss: 2.1945, val_loss: 2.2745
# epoch: 27, step: 72000, train_loss: 2.3967, val_loss: 2.2673
# epoch: 27, step: 72500, train_loss: 2.5043, val_loss: 2.2701
# epoch: 27, step: 73000, train_loss: 2.3139, val_loss: 2.2737
# epoch: 27, step: 73500, train_loss: 2.4309, val_loss: 2.2676
# epoch: 28, step: 74000, train_loss: 2.2663, val_loss: 2.2651
# epoch: 28, step: 74500, train_loss: 2.3401, val_loss: 2.2641
# epoch: 28, step: 75000, train_loss: 2.2399, val_loss: 2.2688
# epoch: 28, step: 75500, train_loss: 2.1427, val_loss: 2.2711
# epoch: 28, step: 76000, train_loss: 2.0492, val_loss: 2.2685
# epoch: 28, step: 76500, train_loss: 2.3051, val_loss: 2.2651
# epoch: 29, step: 77000, train_loss: 2.1531, val_loss: 2.2662
# epoch: 29, step: 77500, train_loss: 2.1759, val_loss: 2.2615
# epoch: 29, step: 78000, train_loss: 2.2715, val_loss: 2.2643
# epoch: 29, step: 78500, train_loss: 2.1932, val_loss: 2.2639
# epoch: 29, step: 79000, train_loss: 2.5160, val_loss: 2.2621

# %%
with torch.no_grad():
    emb = C[X_test].view(X_test.shape[0], -1)
    logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
    val_loss = F.cross_entropy(logits, Y_test)

val_loss
# Out:
# tensor(2.2603)

# %%
# plot embedding
import matplotlib.pyplot as plt

data = C.detach().cpu().numpy()


plt.scatter(data[:, 0], data[:, 1], s=200)
for i, ch in enumerate(chs):
    plt.text(data[i, 0], data[i, 1], ch, ha='center', va='center', color='white')
plt.grid('minor')
plt.show()

# generate text
for _ in range(10):
    idx = torch.zeros(1, 3, dtype=torch.long)
    for _ in range(20):
        context = idx[:, -3:]
        emb = C[context].view(context.shape[0], -1)
        logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
        probs = F.softmax(logits, dim=-1)
        next_idx = torch.multinomial(probs, num_samples=1)
        idx = torch.cat([idx, next_idx], dim=-1)
        if next_idx.item() == 0:
            break
    print(''.join([itos[i.item()] for i in idx[0]]))
# Out:
# ...vanda.
# ...gwa.
# ...lhasaushellean.
# ...kyellien.
# ...kalamilaandel.
# ...hosiovonnemilen.
# ...neh.
# ...roeleigh.
# ...shanni.
# ...stun.

# %% [markdown]
# # scale hidden layer

# %%
n_embd = 2
bs = 64
n_steps = X_train.shape[0] // bs
lr = 0.1
n_epochs = 3

for n_hidden in range(100, 700, 50):

    torch.manual_seed(42)
    g = torch.Generator().manual_seed(42)

    C = torch.randn(27, n_embd)
    w1 = torch.randn(6, n_hidden)
    b1 = torch.randn(n_hidden)
    w2 = torch.randn(n_hidden, 27)
    b2 = torch.randn(27)
    params = [C, w1, b1, w2, b2]
    for p in params:
        p.requires_grad = True



    step = 0
    for epoch in range(n_epochs):


        indices = torch.randperm(X_train.shape[0], generator=g)
        X_tr, Y_tr = X_train[indices], Y_train[indices]
        for s in range(n_steps):
            x = X_tr[s * bs:(s + 1) * bs]
            y = Y_tr[s * bs:(s + 1) * bs]
            emb = C[x].view(x.shape[0], -1)
            logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
            loss = F.cross_entropy(logits, y)
        
            loss.backward()
            if step % 500 == 0:
                with torch.no_grad():
                    emb = C[X_val].view(X_val.shape[0], -1)
                    logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
                    val_loss = F.cross_entropy(logits, Y_val)
            for p in params:
                p.data -= lr * p.grad
                p.grad = None
            
            step += 1
        
    print(f"n_hidden: {n_hidden}, val_loss: {val_loss.item():.4f}")
# Out:
# n_hidden: 100, val_loss: 2.4143
# n_hidden: 150, val_loss: 2.4432
# n_hidden: 200, val_loss: 2.4774
# n_hidden: 250, val_loss: 2.5293
# n_hidden: 300, val_loss: 2.5011
# n_hidden: 350, val_loss: 2.6146
# n_hidden: 400, val_loss: 2.7190
# n_hidden: 450, val_loss: 2.6410
# n_hidden: 500, val_loss: 2.7278
# n_hidden: 550, val_loss: 3.0026
# n_hidden: 600, val_loss: 3.0901
# n_hidden: 650, val_loss: 2.9924

# %% [markdown]
# when scaling hidden layer does not work, the bottleneck may be the embedding layer

# %%
n_hidden = 100
bs = 64
n_steps = X_train.shape[0] // bs
lr = 0.1
n_epochs = 3

for n_embd in range(2, 11):

    torch.manual_seed(42)
    g = torch.Generator().manual_seed(42)

    C = torch.randn(27, n_embd)
    w1 = torch.randn(3 * n_embd, n_hidden)
    b1 = torch.randn(n_hidden)
    w2 = torch.randn(n_hidden, 27)
    b2 = torch.randn(27)
    params = [C, w1, b1, w2, b2]
    for p in params:
        p.requires_grad = True



    step = 0
    for epoch in range(n_epochs):


        indices = torch.randperm(X_train.shape[0], generator=g)
        X_tr, Y_tr = X_train[indices], Y_train[indices]
        for s in range(n_steps):
            x = X_tr[s * bs:(s + 1) * bs]
            y = Y_tr[s * bs:(s + 1) * bs]
            emb = C[x].view(x.shape[0], -1)
            logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
            loss = F.cross_entropy(logits, y)
        
            loss.backward()
            if step % 500 == 0:
                with torch.no_grad():
                    emb = C[X_val].view(X_val.shape[0], -1)
                    logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
                    val_loss = F.cross_entropy(logits, Y_val)
            for p in params:
                p.data -= lr * p.grad
                p.grad = None
            
            step += 1
        
    print(f"n_embd: {n_embd}, val_loss: {val_loss.item():.4f}")
# Out:
# n_embd: 2, val_loss: 2.4143
# n_embd: 3, val_loss: 2.4279
# n_embd: 4, val_loss: 2.3991
# n_embd: 5, val_loss: 2.3807
# n_embd: 6, val_loss: 2.4189
# n_embd: 7, val_loss: 2.4024
# n_embd: 8, val_loss: 2.3757
# n_embd: 9, val_loss: 2.3898
# n_embd: 10, val_loss: 2.3849

# %%
n_embd = 10
n_hidden = 200
bs = 64
n_steps = X_train.shape[0] // bs
ini_lr = 0.1
n_epochs = 30


torch.manual_seed(42)
g = torch.Generator().manual_seed(42)

C = torch.randn(27, n_embd)
w1 = torch.randn(3 * n_embd, n_hidden)
b1 = torch.randn(n_hidden)
w2 = torch.randn(n_hidden, 27)
b2 = torch.randn(27)
params = [C, w1, b1, w2, b2]
for p in params:
    p.requires_grad = True



step = 0
for epoch in range(n_epochs):


    indices = torch.randperm(X_train.shape[0], generator=g)
    X_tr, Y_tr = X_train[indices], Y_train[indices]
    for s in range(n_steps):
        x = X_tr[s * bs:(s + 1) * bs]
        y = Y_tr[s * bs:(s + 1) * bs]
        emb = C[x].view(x.shape[0], -1)
        logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
        loss = F.cross_entropy(logits, y)
    
        loss.backward()
        if step % 500 == 0:
            with torch.no_grad():
                emb = C[X_val].view(X_val.shape[0], -1)
                logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
                val_loss = F.cross_entropy(logits, Y_val)
            print(f"epoch: {epoch}, step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")
        for p in params:
            p.data -= lr * p.grad
            p.grad = None
        
        step += 1
        lr = ini_lr * (1 - 0.9 * step / n_steps / n_epochs)
# Out:
# epoch: 0, step: 0, train_loss: 28.9623, val_loss: 26.6552
# epoch: 0, step: 500, train_loss: 5.4492, val_loss: 4.7470
# epoch: 0, step: 1000, train_loss: 3.6939, val_loss: 3.6344
# epoch: 0, step: 1500, train_loss: 3.3021, val_loss: 3.1032
# epoch: 0, step: 2000, train_loss: 3.1161, val_loss: 2.9202
# epoch: 0, step: 2500, train_loss: 2.8521, val_loss: 2.8268
# epoch: 1, step: 3000, train_loss: 2.6151, val_loss: 2.7451
# epoch: 1, step: 3500, train_loss: 2.6302, val_loss: 2.7027
# epoch: 1, step: 4000, train_loss: 2.9701, val_loss: 2.6659
# epoch: 1, step: 4500, train_loss: 2.6582, val_loss: 2.6127
# epoch: 1, step: 5000, train_loss: 2.1126, val_loss: 2.5402
# epoch: 2, step: 5500, train_loss: 2.5075, val_loss: 2.5726
# epoch: 2, step: 6000, train_loss: 2.6402, val_loss: 2.5555
# epoch: 2, step: 6500, train_loss: 2.4457, val_loss: 2.4999
# epoch: 2, step: 7000, train_loss: 2.2149, val_loss: 2.4824
# epoch: 2, step: 7500, train_loss: 2.6598, val_loss: 2.4937
# epoch: 3, step: 8000, train_loss: 2.4000, val_loss: 2.4795
# epoch: 3, step: 8500, train_loss: 2.5822, val_loss: 2.4819
# epoch: 3, step: 9000, train_loss: 2.2119, val_loss: 2.4571
# epoch: 3, step: 9500, train_loss: 2.8039, val_loss: 2.4795
# epoch: 3, step: 10000, train_loss: 2.4588, val_loss: 2.4368
# epoch: 3, step: 10500, train_loss: 2.6505, val_loss: 2.4773
# epoch: 4, step: 11000, train_loss: 2.6492, val_loss: 2.4596
# epoch: 4, step: 11500, train_loss: 2.3236, val_loss: 2.4326
# epoch: 4, step: 12000, train_loss: 2.2406, val_loss: 2.4132
# epoch: 4, step: 12500, train_loss: 2.2575, val_loss: 2.4061
# epoch: 4, step: 13000, train_loss: 2.4322, val_loss: 2.4429
# epoch: 5, step: 13500, train_loss: 2.2719, val_loss: 2.4028
# epoch: 5, step: 14000, train_loss: 1.9317, val_loss: 2.4152
# epoch: 5, step: 14500, train_loss: 2.2473, val_loss: 2.3872
shape[0], -1)
    logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
    val_loss = F.cross_entropy(logits, Y_test)

val_loss
# Out:
# tensor(2.2087)

# %% [markdown]
# # further improve

# %%
# use different number of characters
for n_chs in range(2, 11):

    X, Y = [], []
    for w in words:
        context = '.' * n_chs
        for ch in w + '.':
            x = [stoi[c] for c in context]
            y = stoi[ch]
            X.append(x)
            Y.append(y)
            context = context[1:] + ch

    X = torch.tensor(X)
    Y = torch.tensor(Y)
    n1, n2  = int(0.8 * len(X)), int(0.9 * len(X))

    X_train, X_val, X_test = X.tensor_split([n1, n2])
    Y_train, Y_val, Y_test = Y.tensor_split([n1, n2])

    n_embd = 10
    n_hidden = 200
    bs = 32
    lr = 0.1


    torch.manual_seed(42)
    g = torch.Generator().manual_seed(42)

    C = torch.randn(27, n_embd)
    w1 = torch.randn(n_chs * n_embd, n_hidden)
    b1 = torch.randn(n_hidden)
    w2 = torch.randn(n_hidden, 27)
    b2 = torch.randn(27)
    params = [C, w1, b1, w2, b2]
    for p in params:
        p.requires_grad = True


    n_steps = 10000
    for step in range(n_steps):
        indices = torch.randint(0, X_train.shape[0], (bs,), generator=g)
        x, y = X_train[indices], Y_train[indices]
        emb = C[x].view(x.shape[0], -1)
        logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
        loss = F.cross_entropy(logits, y)

        loss.backward()
        for p in params:
            p.data -= lr * p.grad
            p.grad = None
        
    with torch.no_grad():
        emb = C[X_val].view(X_val.shape[0], -1)
        logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
        val_loss = F.cross_entropy(logits, Y_val)
    print(f"n_chs: {n_chs}, step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")
# Out:
# n_chs: 2, step: 9999, train_loss: 2.2829, val_loss: 2.6155
# n_chs: 3, step: 9999, train_loss: 2.4316, val_loss: 2.5614
# n_chs: 4, step: 9999, train_loss: 2.4968, val_loss: 2.4645
# n_chs: 5, step: 9999, train_loss: 2.5278, val_loss: 2.6192
# n_chs: 6, step: 9999, train_loss: 2.8849, val_loss: 2.7413
# n_chs: 7, step: 9999, train_loss: 2.6555, val_loss: 2.7669
# n_chs: 8, step: 9999, train_loss: 2.5464, val_loss: 2.7570
# n_chs: 9, step: 9999, train_loss: 2.9392, val_loss: 2.7761
# n_chs: 10, step: 9999, train_loss: 2.9209, val_loss: 2.8729

# %%
n_chs = 3
n_embd = 10
n_hidden = 200
bs = 64
lr = 0.3

X, Y = [], []
for w in words:
    context = '.' * n_chs
    for ch in w + '.':
        x = [stoi[c] for c in context]
        y = stoi[ch]
        X.append(x)
        Y.append(y)
        context = context[1:] + ch

X = torch.tensor(X)
Y = torch.tensor(Y)
n1, n2  = int(0.8 * len(X)), int(0.9 * len(X))

X_train, X_val, X_test = X.tensor_split([n1, n2])
Y_train, Y_val, Y_test = Y.tensor_split([n1, n2])




torch.manual_seed(42)
g = torch.Generator().manual_seed(42)

C = torch.randn(27, n_embd)
w1 = torch.randn(n_chs * n_embd, n_hidden)
b1 = torch.randn(n_hidden)
w2 = torch.randn(n_hidden, 27)
b2 = torch.randn(27)
params = [C, w1, b1, w2, b2]
for p in params:
    p.requires_grad = True



n_steps = 50000
for step in range(n_steps):
    indices = torch.randint(0, X_train.shape[0], (bs,), generator=g)
    x, y = X_train[indices], Y_train[indices]
    emb = C[x].view(x.shape[0], -1)
    logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
    loss = F.cross_entropy(logits, y)

    loss.backward()
    if step % 500 == 0:
        with torch.no_grad():
            emb = C[X_val].view(X_val.shape[0], -1)
            logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
            val_loss = F.cross_entropy(logits, Y_val)
        print(f"step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")
    for p in params:
        p.data -= lr * p.grad
        p.grad = None
    
    lr = ini_lr if step < n_steps // 2 else ini_lr * 0.1
# Out:
# step: 0, train_loss:
# step: 28500, train_loss: 1.9698, val_loss: 2.2422
# step: 29000, train_loss: 2.3369, val_loss: 2.2363
# step: 29500, train_loss: 2.4321, val_loss: 2.2385
# step: 30000, train_loss: 2.1959, val_loss: 2.2433
# step: 30500, train_loss: 2.3824, val_loss: 2.2370
# step: 31000, train_loss: 2.5094, val_loss: 2.2399
# step: 31500, train_loss: 2.2617, val_loss: 2.2420
# step: 32000, train_loss: 2.1735, val_loss: 2.2372
# step: 32500, train_loss: 1.9850, val_loss: 2.2383
# step: 33000, train_loss: 2.0839, val_loss: 2.2398
# step: 33500, train_loss: 2.2749, val_loss: 2.2388
# step: 34000, train_loss: 2.1405, val_loss: 2.2357
# step: 34500, train_loss: 1.9963, val_loss: 2.2371
# step: 35000, train_loss: 1.8489, val_loss: 2.2400
# step: 35500, train_loss: 2.1124, val_loss: 2.2352
# step: 36000, train_loss: 2.4506, val_loss: 2.2350
# step: 36500, train_loss: 1.9094, val_loss: 2.2369
# step: 37000, train_loss: 2.1441, val_loss: 2.2356
# step: 37500, train_loss: 2.1814, val_loss: 2.2397
# step: 38000, train_loss: 2.1785, val_loss: 2.2381
# step: 38500, train_loss: 2.1441, val_loss: 2.2361
# step: 39000, train_loss: 2.1344, val_loss: 2.2343
# step: 39500, train_loss: 2.1335, val_loss: 2.2359
# step: 40000, train_loss: 2.3002, val_loss: 2.2357
# step: 40500, train_loss: 2.2735, val_loss: 2.2367
# step: 41000, train_loss: 2.3122, val_loss: 2.2341
# step: 41500, train_loss: 2.0733, val_loss: 2.2370
# step: 42000, train_loss: 2.4208, val_loss: 2.2376
# step: 42500, train_loss: 2.1183, val_loss: 2.2351
# step: 43000, train_loss: 2.1877, val_loss: 2.2344
# step: 43500, train_loss: 2.3458, val_loss: 2.2357
# step: 44000, train_loss: 2.0769, val_loss: 2.2375
# step: 44500, train_loss: 2.3943, val_loss: 2.2398
# step: 45000, train_loss: 2.3813, val_loss: 2.2357
# step: 45500, train_loss: 2.1922, val_loss: 2.2383
# step: 46000, train_loss: 2.2608, val_loss: 2.2340
# step: 46500, train_loss: 2.0843, val_loss: 2.2341
# step: 47000, train_loss: 1.8142, val_loss: 2.2322
# step: 47500, train_loss: 2.4173, val_loss: 2.2347
# step: 48000, train_loss: 2.7039, val_loss: 2.2364
# step: 48500, train_loss: 2.2994, val_loss: 2.2327
# step: 49000, train_loss: 1.9703, val_loss: 2.2331
# step: 49500, train_loss: 2.3458, val_loss: 2.2323

# %%
with torch.no_grad():
    emb = C[X_test].view(X_test.shape[0], -1)
    logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
    val_loss = F.cross_entropy(logits, Y_test)

val_loss
# Out:
# tensor(2.2202)

# %% [markdown]
# # play around for lower loss
# - the later the training stage, the smaller the learning rate should be
# - bigger batch size with slightly larger learning rate may help further reduce the loss

# %%
# keep tuning the parameters in this block and re-runing to find the lowest loss

bs = 8192
ini_lr = 0.0025
n_steps = 1000
for step in range(n_steps):
    indices = torch.randint(0, X_train.shape[0], (bs,), generator=g)
    x, y = X_train[indices], Y_train[indices]
    emb = C[x].view(x.shape[0], -1)
    logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
    loss = F.cross_entropy(logits, y)

    loss.backward()
    if step % 100 == 0:
        with torch.no_grad():
            emb = C[X_val].view(X_val.shape[0], -1)
            logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
            val_loss = F.cross_entropy(logits, Y_val)
        print(f"step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")
    for p in params:
        p.data -= lr * p.grad
        p.grad = None
    
    lr = ini_lr # if step < n_steps // 2 else ini_lr * 0.1
# Out:
# step: 0, train_loss: 2.1183, val_loss: 2.1713
# step: 100, train_loss: 2.1117, val_loss: 2.1713
# step: 200, train_loss: 2.1113, val_loss: 2.1714
# step: 300, train_loss: 2.1258, val_loss: 2.1714
# step: 400, train_loss: 2.1324, val_loss: 2.1714
# step: 500, train_loss: 2.1493, val_loss: 2.1714
# step: 600, train_loss: 2.1348, val_loss: 2.1714
# step: 700, train_loss: 2.1439, val_loss: 2.1714
# step: 800, train_loss: 2.1157, val_loss: 2.1714
# step: 900, train_loss: 2.1257, val_loss: 2.1713

# %%
with torch.no_grad():
    emb = C[X_test].view(X_test.shape[0], -1)
    logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
    val_loss = F.cross_entropy(logits, Y_test)

val_loss
# Out:
# tensor(2.1492)

# %%
g = torch.Generator().manual_seed(42)

for _ in range(10):
    idx = torch.zeros(1, 3, dtype=torch.long)
    for _ in range(20):
        context = idx[:, -3:]
        emb = C[context].view(context.shape[0], -1)
        logits = torch.tanh(emb @ w1 + b1) @ w2 + b2
        probs = F.softmax(logits, dim=-1)
        next_idx = torch.multinomial(probs, num_samples=1, generator=g)
        idx = torch.cat([idx, next_idx], dim=-1)
        if next_idx.item() == 0:
            break
    print(''.join([itos[i.item()] for i in idx[0]]))
# Out:
# ...anuelen.
# ...tia.
# ...marian.
# ...dante.
# ...nariel.
# ...yana.
# ...kemah.
# ...lunan.
# ...epiannaleilanzi.
# ...kence.

# %%
# plot embedding
import matplotlib.pyplot as plt

data = C.detach().cpu().numpy()


plt.scatter(data[:, 0], data[:, 1], s=200)
for i, ch in enumerate(chs):
    plt.text(data[i, 0], data[i, 1], ch, ha='center', va='center', color='white')
plt.grid('minor')
plt.title(f'dim 0 and dim 1')
plt.xlabel('dim 0')
plt.ylabel('dim 1')
plt.show()

plt.scatter(data[:, 2], data[:, 3], s=200)
for i, ch in enumerate(chs):
    plt.text(data[i, 2], data[i, 3], ch, ha='center', va='center', color='white')
plt.grid('minor')
plt.title(f'dim 2 and dim 3')
plt.xlabel('dim 2')
plt.ylabel('dim 3')
plt.show()

# %%
import matplotlib.pyplot as plt

# 创建10x10的子图矩阵
fig, axes = plt.subplots(10, 10, figsize=(20, 20))

# 遍历所有维度对组合
for i in range(10):
    for j in range(10):
        ax = axes[i, j]
        
        # 在对角线上显示维度号
        if i == j:
            ax.text(0.5, 0.5, f'dim {i}', ha='center', va='center')
            ax.set_xticks([])
            ax.set_yticks([])
            continue
            
        # 绘制散点图
        ax.scatter(data[:, i], data[:, j], s=50)
        for k, ch in enumerate(chs):
            ax.text(data[k, i], data[k, j], ch, ha='center', va='center', color='white')
            
        # 设置标签
        if i == 9:  # 最后一行
            ax.set_xlabel(f'dim {j}')
        if j == 0:  # 第一列
            ax.set_ylabel(f'dim {i}')
            
        # 移除刻度
        ax.set_xticks([])
        ax.set_yticks([])
        
# 调整子图之间的间距
plt.tight_layout()
plt.show()

# %%
# cosine similarity of rows of C
C_norm = C / C.norm(dim=1, keepdim=True)
data = C_norm @ C_norm.T
data = data.detach().cpu().numpy()

plt.imshow(data[1:,1:], cmap='hot')
plt.xticks(range(26), [chr(i + ord('a')) for i in range(26)])
plt.yticks(range(26), [chr(i + ord('a')) for i in range(26)])
plt.gca().xaxis.set_ticks_position('top')
plt.colorbar()
plt.show()

# inner product of rows of C
data = C @ C.T
data = data.detach().cpu().numpy()

plt.imshow(data[1:,1:], cmap='hot')
plt.xticks(range(26), [chr(i + ord('a')) for i in range(26)])
plt.yticks(range(26), [chr(i + ord('a')) for i in range(26)])
plt.gca().xaxis.set_ticks_position('top')
plt.colorbar()
plt.show()

# %%
c_norm = C.norm(dim=1)
c_norm = c_norm.detach().cpu().numpy()

plt.figure(figsize=(30, 5))
plt.hist(c_norm, bins=100)
plt.xlabel('norm')
plt.ylabel('count')
for i, ch in enumerate(chs):
    plt.text(c_norm[i], 1.1, ch, ha='center', va='center')
plt.show()

# %% [markdown]
# # more model architecture

# %% [markdown]
# ## compare residual and no residual
# residual is little bit better

# %%
import torch.nn as nn


class Net(nn.Module):
    def __init__(self, n_chs, n_embd, n_hidden, residual=False):
        super().__init__()
        self.C = nn.Embedding(27, n_embd)
        self.fc1 = nn.Linear(n_chs * n_embd, n_hidden)
        if residual:
            self.fcd = nn.Linear(n_chs * n_embd, n_hidden, bias=False)
        self.fc2 = nn.Linear(n_hidden, 27)
        self.residual = residual
    
    def forward(self, x):
        emb = self.C(x).view(x.shape[0], -1)
        hidden = torch.tanh(self.fc1(emb))
        if self.residual:
            hidden = hidden + self.fcd(emb)
        logits = self.fc2(hidden)
        return logits

torch.manual_seed(42)
g = torch.Generator().manual_seed(42)

n_chs = 3
n_embd = 10
n_hidden = 200
bs = 64
ini_lr = 0.0025

net1 = Net(n_chs, n_embd, n_hidden, residual=True)
net2 = Net(n_chs, n_embd, n_hidden, residual=False)
optimizer1 = torch.optim.Adam(net1.parameters(), lr=ini_lr)
optimizer2 = torch.optim.Adam(net2.parameters(), lr=ini_lr)

lossi1, lossi2 = [], []

n_steps = 20000
for step in range(n_steps):
    indices = torch.randint(0, X_train.shape[0], (bs,), generator=g)
    x, y = X_train[indices], Y_train[indices]
    logits1 = net1(x)
    loss1 = F.cross_entropy(logits1, y)
    logits2 = net2(x)
    loss2 = F.cross_entropy(logits2, y)

    loss1.backward()
    loss2.backward()
    if step % 500 == 0:
        with torch.no_grad():
            logits1 = net1(X_val)
            val_loss1 = F.cross_entropy(logits1, Y_val)
            logits2 = net2(X_val)
            val_loss2 = F.cross_entropy(logits2, Y_val)
        print(f"step: {step}, train_loss: {loss1.item():.4f}, val_loss: {val_loss1.item():.4f}, train_loss2: {loss2.item():.4f}, val_loss2: {val_loss2.item():.4f}")
        lossi1.append(val_loss1.log().item())
        lossi2.append(val_loss2.log().item())

    optimizer1.step()
    optimizer1.zero_grad()
    optimizer2.step()
    optimizer2.zero_grad()
    
    lr = ini_lr if step < n_steps // 2 else ini_lr * 0.1

plt.plot(lossi1, label='residual')
plt.plot(lossi2, label='no residual')
plt.legend()
plt.show()
# Out:
# step: 0, train_loss: 3.3810, val_loss: 3.4007, train_loss2: 3.3991, val_loss2: 3.3570
# step: 500, train_loss: 2.1407, val_loss: 2.4224, train_loss2: 2.1389, val_loss2: 2.4138
# step: 1000, train_loss: 2.3518, val_loss: 2.3931, train_loss2: 2.3094, val_loss2: 2.3788
# step: 1500, train_loss: 2.1206, val_loss: 2.3379, train_loss2: 2.0756, val_loss2: 2.3342
# step: 2000, train_loss: 2.3165, val_loss: 2.3383, train_loss2: 2.3854, val_loss2: 2.3371
# step: 2500, train_loss: 2.2436, val_loss: 2.3416, train_loss2: 2.1657, val_loss2: 2.3345
# step: 3000, train_loss: 2.3682, val_loss: 2.3181, train_loss2: 2.3803, val_loss2: 2.3088
# step: 3500, train_loss: 2.3107, val_loss: 2.3486, train_loss2: 2.2604, val_loss2: 2.3543
# step: 4000, train_loss: 2.3299, val_loss: 2.2983, train_loss2: 2.3175, val_loss2: 2.2982
# step: 4500, train_loss: 2.2286, val_loss: 2.3063, train_loss2: 2.1573, val_loss2: 2.3005
# step: 5000, train_loss: 2.0037, val_loss: 2.2977, train_loss2: 2.0487, val_loss2: 2.2895
# step: 5500, train_loss: 2.4855, val_loss: 2.3203, train_loss2: 2.3521, val_loss2: 2.3080
# step: 6000, train_loss: 2.3410, val_loss: 2.3149, train_loss2: 2.3610, val_loss2: 2.3034
# step: 6500, train_loss: 2.2824, val_loss: 2.3118, train_loss2: 2.3506, val_loss2: 2.3169
# step: 7000, train_loss: 2.4589, val_loss: 2.2798, train_loss2: 2.4030, val_loss2: 2.2791
# step: 7500, train_loss: 2.1760, val_loss: 2.3119, train_loss2: 2.1439, val_loss2: 2.2935
# step: 8000, train_loss: 2.4441, val_loss: 2.2821, train_loss2: 2.3419, val_loss2: 2.2764
# step: 8500, train_loss: 2.2827, val_loss: 2.2934, train_loss2: 2.2805, val_loss2: 2.2870
# step: 9000, train_loss: 2.2906, val_loss: 2.2894, train_loss2: 2.2263, val_loss2: 2.2881
# step: 9500, train_loss: 2.3052, val_loss: 2.3014, train_loss2: 2.2569, val_loss2: 2.3043
# step: 10000, train_loss: 2.2353, val_loss: 2.2757, train_loss2: 2.2958, val_loss2: 2.2910
# step: 10500, train_loss: 2.1773, val_loss: 2.2822, train_loss2: 2.0903, val_loss2: 2.2944
# step: 11000, train_loss: 2.2412, val_loss: 2.2956, train_loss2: 2.2251, val_loss2: 2.2960
# step: 11500, train_loss: 2.1185, val_loss: 2.2731, train_loss2: 2.3336, val_loss2: 2.2808
# step: 12000, train_loss: 2.0255, val_loss: 2.2742, train_loss2: 2.0081, val_loss2: 2.2833
# step: 12500, train_loss: 2.3666, val_loss: 2.3012, train_loss2: 2.3863, val_loss2: 2.2960
# step: 13000, train_loss: 2.4225, val_loss: 2.2741, train_loss2: 2.4703, val_loss2: 2.2916
# step: 13500, train_loss: 2.1814, val_loss: 2.2796, train_loss2: 2.2435, val_loss2: 2.2820
# step: 14000, train_loss: 2.4654, val_loss: 2.2739, train_loss2: 2.5457, val_loss2: 2.2863
# step: 14500, train_loss: 2.0279, val_loss: 2.2879, train_loss2: 2.0424, val_loss2: 2.2847
# step: 15000, train_loss: 2.2937, val_loss: 2.2774, train_loss2: 2.3378, val_loss2: 2.2784
# step: 15500, train_loss: 2.2411, val_loss: 2.2701, train_loss2: 2.2841, val_loss2: 2.2829
# step: 16000, train_loss: 2.0274, val_loss: 2.2692, train_loss2: 2.0716, val_loss2: 2.2816
# step: 16500, train_loss: 2.0913, val_loss: 2.2976, train_loss2: 2.0675, val_loss2: 2.2996
# step: 17000, train_loss: 2.4283, val_loss: 2.2961, train_loss2: 2.4260, val_loss2: 2.3015
# step: 17500, train_loss: 2.2763, val_loss: 2.2702, train_loss2: 2.3422, val_loss2: 2.2824
# step: 18000, train_loss: 2.1382, val_loss: 2.2858, train_loss2: 2.2032, val_loss2: 2.2924
# step: 18500, train_loss: 2.1049, val_loss: 2.2819, train_loss2: 2.1514, val_loss2: 2.2828
# step: 19000, train_loss: 2.4048, val_loss: 2.2669, train_loss2: 2.4730, val_loss2: 2.2702
# step: 19500, train_loss: 1.9303, val_loss: 2.2958, train_loss2: 1.8826, val_loss2: 2.3125

# %%
with torch.no_grad():
    logits1 = net1(X_test)
    val_loss1 = F.cross_entropy(logits1, Y_test)
    logits2 = net2(X_test)
    val_loss2 = F.cross_entropy(logits2, Y_test)

val_loss1, val_loss2
# Out:
# (tensor(2.2536), tensor(2.2644))

# %%
g = torch.Generator().manual_seed(42)

for _ in range(10):
    idx = torch.zeros(1, 3, dtype=torch.long)
    for _ in range(20):
        context = idx[:, -3:]
        emb = net1.C(context).view(context.shape[0], -1)
        logits = net1(context)
        probs = F.softmax(logits, dim=-1)
        next_idx = torch.multinomial(probs, num_samples=1, generator=g)
        idx = torch.cat([idx, next_idx], dim=-1)
        if next_idx.item() == 0:
            break
    print(''.join([itos[i.item()] for i in idx[0]]))

print()
g = torch.Generator().manual_seed(42)

for _ in range(10):
    idx = torch.zeros(1, 3, dtype=torch.long)
    for _ in range(20):
        context = idx[:, -3:]
        emb = net2.C(context).view(context.shape[0], -1)
        logits = net2(context)
        probs = F.softmax(logits, dim=-1)
        next_idx = torch.multinomial(probs, num_samples=1, generator=g)
        idx = torch.cat([idx, next_idx], dim=-1)
        if next_idx.item() == 0:
            break
    print(''.join([itos[i.item()] for i in idx[0]]))
# Out:
# ...anueden.
# ...tis.
# ...marian.
# ...dante.
# ...namillaylen.
# ...keman.
# ...luman.
# ...epracellen.
# ...dazi.
# ...ana.
#
# ...anueden.
# ...tie.
# ...mariel.
# ...dante.
# ...nariel.
# ...yana.
# ...kemah.
# ...lunan.
# ...epracelle.
# ...jamzi.

# %% [markdown]
# ##  better activation function

# %%
import torch.nn as nn


class Net(nn.Module):
    def __init__(self, n_chs, n_embd, n_hidden):
        super().__init__()
        self.C = nn.Embedding(27, n_embd)
        self.fc1 = nn.Linear(n_chs * n_embd, n_hidden)
        self.fcd = nn.Linear(n_chs * n_embd, n_hidden, bias=False)
        self.fc2 = nn.Linear(n_hidden, 27)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        emb = self.C(x).view(x.shape[0], -1)
        hidden = self.relu(self.fc1(emb)) + self.fcd(emb)
        logits = self.fc2(hidden)
        return logits

torch.manual_seed(42)
g = torch.Generator().manual_seed(42)

n_chs = 3
n_embd = 10
n_hidden = 200
bs = 64
ini_lr = 0.0025

net = Net(n_chs, n_embd, n_hidden)
optimizer = torch.optim.Adam(net.parameters(), lr=ini_lr)


n_steps = 5000
for step in range(n_steps):
    indices = torch.randint(0, X_train.shape[0], (bs,), generator=g)
    x, y = X_train[indices], Y_train[indices]
    logits = net(x)
    loss = F.cross_entropy(logits, y)

    loss.backward()
    if step % 500 == 0:
        with torch.no_grad():
            logits = net(X_val)
            val_loss = F.cross_entropy(logits, Y_val)
        print(f"step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")

    optimizer.step()
    optimizer.zero_grad()
    
    lr = ini_lr if step < n_steps // 2 else ini_lr * 0.1
# Out:
# step: 0, train_loss: 3.4185, val_loss: 3.4159
# step: 500, train_loss: 2.0892, val_loss: 2.3773
# step: 1000, train_loss: 2.3407, val_loss: 2.3556
# step: 1500, train_loss: 2.0465, val_loss: 2.3001
# step: 2000, train_loss: 2.2837, val_loss: 2.2889
# step: 2500, train_loss: 2.1628, val_loss: 2.2770
# step: 3000, train_loss: 2.3029, val_loss: 2.2694
# step: 3500, train_loss: 2.2446, val_loss: 2.2652
# step: 4000, train_loss: 2.2880, val_loss: 2.2483
# step: 4500, train_loss: 2.1219, val_loss: 2.2348

# %% [markdown]
# ## more layers

# %%
class Net(nn.Module):
    def __init__(self, n_chs, n_embd, n_hidden):
        super().__init__()
        self.C = nn.Embedding(27, n_embd)
        self.fc1 = nn.Linear(n_chs * n_embd, n_hidden)
        self.fcd = nn.Linear(n_chs * n_embd, n_hidden, bias=False)
        self.fc2 = nn.Linear(n_hidden, n_hidden)
        self.fc3 = nn.Linear(n_hidden, 27)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        emb = self.C(x).view(x.shape[0], -1)
        hidden = self.relu(self.fc1(emb)) + self.fcd(emb)
        hidden = self.relu(self.fc2(hidden)) + hidden
        logits = self.fc3(hidden)
        return logits

torch.manual_seed(42)
g = torch.Generator().manual_seed(42)

n_chs = 3
n_embd = 10
n_hidden = 200
bs = 64
ini_lr = 0.0025

net = Net(n_chs, n_embd, n_hidden)
optimizer = torch.optim.Adam(net.parameters(), lr=ini_lr)


n_steps = 10000
for step in range(n_steps):
    indices = torch.randint(0, X_train.shape[0], (bs,), generator=g)
    x, y = X_train[indices], Y_train[indices]
    logits = net(x)
    loss = F.cross_entropy(logits, y)

    loss.backward()
    if step % 500 == 0:
        with torch.no_grad():
            logits = net(X_val)
            val_loss = F.cross_entropy(logits, Y_val)
        print(f"step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")

    optimizer.step()
    optimizer.zero_grad()
    
    lr = ini_lr if step < n_steps // 2 else ini_lr * 0.1
# Out:
# step: 0, train_loss: 3.5222, val_loss: 3.4600
# step: 500, train_loss: 2.1025, val_loss: 2.3587
# step: 1000, train_loss: 2.3403, val_loss: 2.3558
# step: 1500, train_loss: 2.0259, val_loss: 2.2852
# step: 2000, train_loss: 2.1703, val_loss: 2.2827
# step: 2500, train_loss: 2.1875, val_loss: 2.2594
# step: 3000, train_loss: 2.3041, val_loss: 2.2451
# step: 3500, train_loss: 2.2240, val_loss: 2.2416
# step: 4000, train_loss: 2.2640, val_loss: 2.2278
# step: 4500, train_loss: 2.0761, val_loss: 2.2163
# step: 5000, train_loss: 2.0268, val_loss: 2.2264
# step: 5500, train_loss: 2.3119, val_loss: 2.2432
# step: 6000, train_loss: 2.2956, val_loss: 2.2138
# step: 6500, train_loss: 2.2615, val_loss: 2.2135
# step: 7000, train_loss: 2.3135, val_loss: 2.2035
# step: 7500, train_loss: 1.9859, val_loss: 2.2134
# step: 8000, train_loss: 2.3249, val_loss: 2.2031
# step: 8500, train_loss: 2.1696, val_loss: 2.2061
# step: 9000, train_loss: 2.1559, val_loss: 2.2030
# step: 9500, train_loss: 2.1501, val_loss: 2.2097

# %%
class Net(nn.Module):
    def __init__(self, n_chs, n_embd, n_hidden):
        super().__init__()
        self.C = nn.Embedding(27, n_embd)
        self.fc1 = nn.Linear(n_chs * n_embd, n_hidden)
        self.fcd = nn.Linear(n_chs * n_embd, n_hidden, bias=False)
        self.fc2 = nn.Linear(n_hidden, n_hidden)
        self.fc3 = nn.Linear(n_hidden, n_hidden)
        self.fc4 = nn.Linear(n_hidden, 27)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        emb = self.C(x).view(x.shape[0], -1)
        hidden = self.relu(self.fc1(emb)) + self.fcd(emb)
        hidden = self.relu(self.fc2(hidden)) + hidden
        hidden = self.relu(self.fc3(hidden)) + hidden
        logits = self.fc4(hidden)
        return logits

torch.manual_seed(42)
g = torch.Generator().manual_seed(42)

n_chs = 3
n_embd = 10
n_hidden = 200
bs = 64
ini_lr = 0.0025

net = Net(n_chs, n_embd, n_hidden)
optimizer = torch.optim.Adam(net.parameters(), lr=ini_lr)


n_steps = 10000
for step in range(n_steps):
    indices = torch.randint(0, X_train.shape[0], (bs,), generator=g)
    x, y = X_train[indices], Y_train[indices]
    logits = net(x)
    loss = F.cross_entropy(logits, y)

    loss.backward()
    if step % 500 == 0:
        with torch.no_grad():
            logits = net(X_val)
            val_loss = F.cross_entropy(logits, Y_val)
        print(f"step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")

    optimizer.step()
    optimizer.zero_grad()
    
    lr = ini_lr if step < n_steps // 2 else ini_lr * 0.1
# Out:
# step: 0, train_loss: 3.3715, val_loss: 3.5573
# step: 500, train_loss: 2.0448, val_loss: 2.3627
# step: 1000, train_loss: 2.3171, val_loss: 2.3513
# step: 1500, train_loss: 1.9563, val_loss: 2.2891
# step: 2000, train_loss: 2.2528, val_loss: 2.2883
# step: 2500, train_loss: 2.1014, val_loss: 2.2714
# step: 3000, train_loss: 2.3673, val_loss: 2.2589
# step: 3500, train_loss: 2.1915, val_loss: 2.2453
# step: 4000, train_loss: 2.2722, val_loss: 2.2342
# step: 4500, train_loss: 2.1189, val_loss: 2.2197
# step: 5000, train_loss: 2.0253, val_loss: 2.2117
# step: 5500, train_loss: 2.2841, val_loss: 2.2432
# step: 6000, train_loss: 2.2481, val_loss: 2.2196
# step: 6500, train_loss: 2.2979, val_loss: 2.2220
# step: 7000, train_loss: 2.2811, val_loss: 2.2082
# step: 7500, train_loss: 1.9906, val_loss: 2.2163
# step: 8000, train_loss: 2.3124, val_loss: 2.2106
# step: 8500, train_loss: 2.1695, val_loss: 2.2092
# step: 9000, train_loss: 2.1867, val_loss: 2.2152
# step: 9500, train_loss: 2.1932, val_loss: 2.2077

# %%
class Net(nn.Module):
    def __init__(self, n_chs, n_embd, n_hidden):
        super().__init__()
        self.C = nn.Embedding(27, n_embd)
        self.fc1 = nn.Linear(n_chs * n_embd, n_hidden)
        self.fcd = nn.Linear(n_chs * n_embd, n_hidden, bias=False)
        self.fc2 = nn.Linear(n_hidden, n_hidden)
        self.fc3 = nn.Linear(n_hidden, n_hidden)
        self.fc4 = nn.Linear(n_hidden, n_hidden)
        self.fc5 = nn.Linear(n_hidden, n_hidden)
        self.fc6 = nn.Linear(n_hidden, n_hidden)
        self.fco = nn.Linear(n_hidden, 27)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        emb = self.C(x).view(x.shape[0], -1)
        hidden = self.relu(self.fc1(emb)) + self.fcd(emb)
        hidden = self.relu(self.fc2(hidden)) + hidden
        hidden = self.relu(self.fc3(hidden)) + hidden
        hidden = self.relu(self.fc4(hidden)) + hidden
        hidden = self.relu(self.fc5(hidden)) + hidden
        hidden = self.relu(self.fc6(hidden)) + hidden
        logits = self.fco(hidden)
        return logits

torch.manual_seed(42)
g = torch.Generator().manual_seed(42)

n_chs = 3
n_embd = 10
n_hidden = 200
bs = 64
ini_lr = 0.0025

net = Net(n_chs, n_embd, n_hidden)
optimizer = torch.optim.Adam(net.parameters(), lr=ini_lr)


n_steps = 10000
for step in range(n_steps):
    indices = torch.randint(0, X_train.shape[0], (bs,), generator=g)
    x, y = X_train[indices], Y_train[indices]
    logits = net(x)
    loss = F.cross_entropy(logits, y)

    loss.backward()
    if step % 500 == 0:
        with torch.no_grad():
            logits = net(X_val)
            val_loss = F.cross_entropy(logits, Y_val)
        print(f"step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")

    optimizer.step()
    optimizer.zero_grad()
    
    lr = ini_lr if step < n_steps // 2 else ini_lr * 0.1
# Out:
# step: 0, train_loss: 3.6925, val_loss: 3.4936
# step: 500, train_loss: 2.1255, val_loss: 2.3353
# step: 1000, train_loss: 2.2628, val_loss: 2.2945
# step: 1500, train_loss: 1.9780, val_loss: 2.2491
# step: 2000, train_loss: 2.2032, val_loss: 2.2335
# step: 2500, train_loss: 2.0559, val_loss: 2.2282
# step: 3000, train_loss: 2.2796, val_loss: 2.2163
# step: 3500, train_loss: 2.1438, val_loss: 2.2019
# step: 4000, train_loss: 2.2158, val_loss: 2.1910
# step: 4500, train_loss: 2.0426, val_loss: 2.1790
# step: 5000, train_loss: 2.0710, val_loss: 2.1731
# step: 5500, train_loss: 2.2358, val_loss: 2.1957
# step: 6000, train_loss: 2.2253, val_loss: 2.1764
# step: 6500, train_loss: 2.2224, val_loss: 2.1720
# step: 7000, train_loss: 2.2160, val_loss: 2.1608
# step: 7500, train_loss: 1.9474, val_loss: 2.1645
# step: 8000, train_loss: 2.1668, val_loss: 2.1620
# step: 8500, train_loss: 2.0605, val_loss: 2.1637
# step: 9000, train_loss: 2.0934, val_loss: 2.1570
# step: 9500, train_loss: 2.1083, val_loss: 2.1587

# %%
class Net(nn.Module):
    def __init__(self, n_chs, n_embd, n_hidden):
        super().__init__()
        self.C = nn.Embedding(27, n_embd)
        self.fc1 = nn.Linear(n_chs * n_embd, n_hidden)
        self.fcd = nn.Linear(n_chs * n_embd, n_hidden, bias=False)
        self.fc2 = nn.Linear(n_hidden, n_hidden)
        self.fc3 = nn.Linear(n_hidden, n_hidden)
        self.fc4 = nn.Linear(n_hidden, n_hidden)
        self.fc5 = nn.Linear(n_hidden, n_hidden)
        self.fc6 = nn.Linear(n_hidden, n_hidden)
        self.fc7 = nn.Linear(n_hidden, n_hidden)
        self.fc8 = nn.Linear(n_hidden, n_hidden)
        self.fc9 = nn.Linear(n_hidden, n_hidden)
        self.fc10 = nn.Linear(n_hidden, n_hidden)
        self.fco = nn.Linear(n_hidden, 27)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        emb = self.C(x).view(x.shape[0], -1)
        hidden = self.relu(self.fc1(emb)) + self.fcd(emb)
        hidden = self.relu(self.fc2(hidden)) + hidden
        hidden = self.relu(self.fc3(hidden)) + hidden
        hidden = self.relu(self.fc4(hidden)) + hidden
        hidden = self.relu(self.fc5(hidden)) + hidden
        hidden = self.relu(self.fc6(hidden)) + hidden
        hidden = self.relu(self.fc7(hidden)) + hidden
        hidden = self.relu(self.fc8(hidden)) + hidden
        hidden = self.relu(self.fc9(hidden)) + hidden
        hidden = self.relu(self.fc10(hidden)) + hidden
        logits = self.fco(hidden)
        return logits

torch.manual_seed(42)
g = torch.Generator().manual_seed(42)

n_chs = 3
n_embd = 10
n_hidden = 200
bs = 64
ini_lr = 0.001

net = Net(n_chs, n_embd, n_hidden)
optimizer = torch.optim.Adam(net.parameters(), lr=ini_lr)


n_steps = 20000
for step in range(n_steps):
    indices = torch.randint(0, X_train.shape[0], (bs,), generator=g)
    x, y = X_train[indices], Y_train[indices]
    logits = net(x)
    loss = F.cross_entropy(logits, y)

    loss.backward()
    if step % 500 == 0:
        with torch.no_grad():
            logits = net(X_val)
            val_loss = F.cross_entropy(logits, Y_val)
        print(f"step: {step}, train_loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")

    optimizer.step()
    optimizer.zero_grad()
    
    lr = ini_lr if step < n_steps // 2 else ini_lr * 0.1
# Out:
# step: 0, train_loss: 7.0655, val_loss: 6.9590
# step: 500, train_loss: 2.1333, val_loss: 2.3345
# step: 1000, train_loss: 2.2982, val_loss: 2.2984
# step: 1500, train_loss: 1.9657, val_loss: 2.2445
# step: 2000, train_loss: 2.1658, val_loss: 2.2296
# step: 2500, train_loss: 2.0976, val_loss: 2.2261
# step: 3000, train_loss: 2.2428, val_loss: 2.2173
# step: 3500, train_loss: 2.1374, val_loss: 2.2010
# step: 4000, train_loss: 2.1956, val_loss: 2.1951
# step: 4500, train_loss: 2.0711, val_loss: 2.1793
# step: 5000, train_loss: 2.0292, val_loss: 2.1746
# step: 5500, train_loss: 2.2163, val_loss: 2.1921
# step: 6000, train_loss: 2.2278, val_loss: 2.1787
# step: 6500, train_loss: 2.2263, val_loss: 2.1699
# step: 7000, train_loss: 2.2113, val_loss: 2.1658
# step: 7500, train_loss: 1.9336, val_loss: 2.1608
# step: 8000, train_loss: 2.1491, val_loss: 2.1612
# step: 8500, train_loss: 2.1020, val_loss: 2.1635
# step: 9000, train_loss: 2.0311, val_loss: 2.1589
# step: 9500, train_loss: 2.0923, val_loss: 2.1618
# step: 10000, train_loss: 2.0870, val_loss: 2.1627
# step: 10500, train_loss: 1.9257, val_loss: 2.1613
# step: 11000, train_loss: 2.1045, val_loss: 2.1535
# step: 11500, train_loss: 2.0924, val_loss: 2.1607
# step: 12000, train_loss: 1.9654, val_loss: 2.1506
# step: 12500, train_loss: 2.1549, val_loss: 2.1513
# step: 13000, train_loss: 2.2897, val_loss: 2.1466
# step: 13500, train_loss: 2.1653, val_loss: 2.1559
# step: 14000, train_loss: 2.1888, val_loss: 2.1474
# step: 14500, train_loss: 1.8855, val_loss: 2.1473
# step: 15000, train_loss: 2.2753, val_loss: 2.1497
# step: 15500, train_loss: 1.9602, val_loss: 2.1481
# step: 16000, train_loss: 1.8738, val_loss: 2.1468
# step: 16500, train_loss: 1.8980, val_loss: 2.1481
# step: 17000, train_loss: 2.2876, val_loss: 2.1451
# step: 17500, train_loss: 2.0878, val_loss: 2.1386
# step: 18000, train_loss: 2.0594, val_loss: 2.1379
# step: 18500, train_loss: 1.9592, val_loss: 2.1441
# step: 19000, train_loss: 2.1846, val_loss: 2.1416
# step: 19500, train_loss: 1.7867, val_loss: 2.1515

# %%
with torch.no_grad():
    logits = net(X_test)
    val_loss = F.cross_entropy(logits, Y_test)

val_loss
# Out:
# tensor(2.1326)

# %%
g = torch.Generator().manual_seed(42)

for _ in range(10):
    idx = torch.zeros(1, 3, dtype=torch.long)
    for _ in range(20):
        context = idx[:, -3:]
        emb = net.C(context).view(context.shape[0], -1)
        logits = net(context)
        probs = F.softmax(logits, dim=-1)
        next_idx = torch.multinomial(probs, num_samples=1, generator=g)
        idx = torch.cat([idx, next_idx], dim=-1)
        if next_idx.item() == 0:
            break
    print(''.join([itos[i.item()] for i in idx[0]]))
# Out:
# ...anuelen.
# ...tis.
# ...marian.
# ...danie.
# ...naziya.
# ...yana.
# ...kemah.
# ...lucin.
# ...emiah.
# ...nasilaniy.
